# %%
import os,json
from tqdm.notebook import tqdm

import pandas as pd

# %%
path = '../../data/labelled/'

data = {}

for subdir in os.listdir(path):
    if os.path.isdir(os.path.join(path, subdir)):
        print(subdir)
        for file in tqdm(os.listdir(os.path.join(path, subdir))):
            if file.endswith('.json'):
                with open(os.path.join(path, subdir, file), 'r') as f:
                    data[file] = json.load(f)

data = pd.DataFrame.from_dict(data,orient='index')
data.head()
# Out:
# synopses
#   0%|          | 0/42 [00:00<?, ?it/s]
# scraped
#   0%|          | 0/85 [00:00<?, ?it/s]
# studies
#   0%|          | 0/10105 [00:00<?, ?it/s]
#                                                    reference type author  \
# 10 - Invasive Freshwater Species.json                    CE Study   None
# 14 - Sustainable Aquaculture.json                        CE Study   None
# 17 - Shrubland and Heathland.json                        CE Study   None
# 23 - Peatland.json                                       CE Study   None
# 13 - Biodiversity of Marine Artificial Structur...       CE Study   None
#
#                                                     year  \
# 10 - Invasive Freshwater Species.json               None
# 14 - Sustainable Aquaculture.json                   None
# 17 - Shrubland and Heathland.json                   None
# 23 - Peatland.json                                  None
# 13 - Biodiversity of Marine Artificial Structur...  None
#
#                                                                                            title  \
# 10 - Invasive Freshwater Species.json                                Invasive Freshwater Species
# 14 - Sustainable Aquaculture.json                                        Sustainable Aquaculture
# 17 - Shrubland and Heathland.json                                        Shrubland and Heathland
# 23 - Peatland.json                                                                      Peatland
# 13 - Biodiversity of Marine Artificial Structur...  Biodiversity of Marine Artificial Structures
#
#                                                     series editor  \
# 10 - Invasive Freshwater Species.json                         NaN
# 14 - Sustainable Aquaculture.json                             NaN
# 17 - Shrubland and Heathland.json                             NaN
# 23 - Peatland.json                                            NaN
# 13 - Biodiversity of Marine Artificial Structur...            NaN
#
#                                                    series/book title  \
# 10 - Invasive Freshwater Species.json                           None
# 14 - Sustainable Aquaculture.json                               None
# 17 - Shrubland and Heathland.json                               None
# 23 - Peatland.json                                              None
# 13 - Biodiversity of Marine Artificial Structur...              None
#
#                                                    place published  \
# 10 - Invasive Freshwater Species.json                         None
# 14 - Sustainable Aquaculture.json                             None
# 17 - Shrubland and Heathland.json                             None
# 23 - Peatland.json                                            None
# 13 - Biodiversity of Marine Artificial Structur...            None
#
#                                                                    institution  \
# 10 - Invasive Freshwater Species.json               Conservation Evidence Team
# 14 - Sustainable Aquaculture.json                   Conservation Evidence Team
# 17 - Shrubland and Heathland.json                   Conservation Evidence Team
# 23 - Peatland.json                                  Conservation Evidence Team
# 13 - Biodiversity of Marine Artificial Structur...  Conservation Evidence Team
#
#                                                                 publisher  \
# 10 - Invasive Freshwater Species.json               Conservation Evidence
# 14 - Sustainable Aquaculture.json                   Conservation Evidence
# 17 - Shrubland and Heathland.json                   Conservation Evidence
# 23 - Peatland.json                                  Conservation Evidence
# 13 - Biodiversity of Marine Artificial Structur...  Conservation Evidence
#
#                                                     date  doi          class  \
# 10 - Invasive Freshwater Species.json               None  NaN  Invasive Fish
# 14 - Sustainable Aquaculture.json                   None  NaN         Marine
# 17 - Shrubland and Heathland.json                   None  NaN      Shrubland
# 23 - Peatland.json                                  None  NaN             ..
# 13 - Biodiversity of Marine Artificial Structur...  None  NaN         Marine
#
#                                                     abstract              url  \
# 10 - Invasive Freshwater Species.json                    NaN             None
# 14 - Sustainable Aquaculture.json                        NaN             None
# 17 - Shrubland and Heathland.json                        NaN             None
# 23 - Peatland.json                                       NaN  PDF-PLACEHOLDER
# 13 - Biodiversity of Marine Artificial Structur...       NaN             None
#
#                                                                                                  text  \
# 10 - Invasive Freshwater Species.json                \n \n   \n  Control of freshwater  \n  invasi...
# 14 - Sustainable Aquaculture.json                   1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 17 - Shrubland and Heathland.json                   1 \n \nPhilip A. Martin, Ricardo Rocha, \nRebe...
# 23 - Peatland.json                                  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 13 - Biodiversity of Marine Artificial Structur...  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
#
#                                                    report number folder
# 10 - Invasive Freshwater Species.json                        NaN    NaN
# 14 - Sustainable Aquaculture.json                            NaN    NaN
# 17 - Shrubland and Heathland.json                            NaN    NaN
# 23 - Peatland.json                                           NaN    NaN
# 13 - Biodiversity of Marine Artificial Structur...           NaN    NaN

# %%
# filter down and drop unknown classes
write_data = data[['url','text','class']].dropna(subset=['class'])
write_data.head()
# Out:
#                                                                 url  \
# 10 - Invasive Freshwater Species.json                          None
# 14 - Sustainable Aquaculture.json                              None
# 17 - Shrubland and Heathland.json                              None
# 23 - Peatland.json                                  PDF-PLACEHOLDER
# 13 - Biodiversity of Marine Artificial Structur...             None
#
#                                                                                                  text  \
# 10 - Invasive Freshwater Species.json                \n \n   \n  Control of freshwater  \n  invasi...
# 14 - Sustainable Aquaculture.json                   1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 17 - Shrubland and Heathland.json                   1 \n \nPhilip A. Martin, Ricardo Rocha, \nRebe...
# 23 - Peatland.json                                  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 13 - Biodiversity of Marine Artificial Structur...  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
#
#                                                             class
# 10 - Invasive Freshwater Species.json               Invasive Fish
# 14 - Sustainable Aquaculture.json                          Marine
# 17 - Shrubland and Heathland.json                       Shrubland
# 23 - Peatland.json                                             ..
# 13 - Biodiversity of Marine Artificial Structur...         Marine

# %%
write_data.to_json('../../data/labelled/relevant.json',orient='records')

# %%
def merge_data():
    relevant = pd.read_json('../../data/labelled/relevant.json',orient='records')
    irrelevant = pd.read_json('../../data/labelled/irrelevant.json',orient='records')
    data = pd.concat([relevant,irrelevant])
    return data

merged_data = merge_data()
print(merged_data.info())
merged_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9538 entries, 0 to 2131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     9520 non-null   object
#  1   text    9538 non-null   object
#  2   class   9538 non-null   object
# dtypes: object(3)
# memory usage: 298.1+ KB
# None
#                url                                               text  \
# 0             None   \n \n   \n  Control of freshwater  \n  invasi...
# 1             None  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 2             None  1 \n \nPhilip A. Martin, Ricardo Rocha, \nRebe...
# 3  PDF-PLACEHOLDER  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
# 4             None  1 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...
#
#            class
# 0  Invasive Fish
# 1         Marine
# 2      Shrubland
# 3             ..
# 4         Marine

# %%
merged_data.to_json('../../data/labelled/data.json',orient='records')
