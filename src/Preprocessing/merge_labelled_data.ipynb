# %%
import os,json
from tqdm.notebook import tqdm

import pandas as pd

# %%
path = '../../data/labelled/'

data = {}

for subdir in os.listdir(path):
    if os.path.isdir(os.path.join(path, subdir)):
        print(subdir)
        for file in tqdm(os.listdir(os.path.join(path, subdir))):
            if file.endswith('.json'):
                with open(os.path.join(path, subdir, file), 'r') as f:
                    data[file] = json.load(f)

data = pd.DataFrame.from_dict(data,orient='index')
data.head()
# Out:
# synopses
#   0%|          | 0/24 [00:00<?, ?it/s]
# scraped
#   0%|          | 0/85 [00:00<?, ?it/s]
# studies
#   0%|          | 0/10105 [00:00<?, ?it/s]
#                                        reference type author  year  \
# 15 - Forest.json                             CE Study   None  None
# 12 - Farmland.json                           CE Study   None  None
# 22 - Natural Pest Control.json               CE Study   None  None
# 3 - Primate.json                             CE Study   None  None
# 0 - Subtidal Benthic Invertebrate.json       CE Study   None  None
#
#                                                                 title  \
# 15 - Forest.json                                               Forest
# 12 - Farmland.json                                           Farmland
# 22 - Natural Pest Control.json                   Natural Pest Control
# 3 - Primate.json                                              Primate
# 0 - Subtidal Benthic Invertebrate.json  Subtidal Benthic Invertebrate
#
#                                         series editor series/book title  \
# 15 - Forest.json                                  NaN              None
# 12 - Farmland.json                                NaN              None
# 22 - Natural Pest Control.json                    NaN              None
# 3 - Primate.json                                  NaN              None
# 0 - Subtidal Benthic Invertebrate.json            NaN              None
#
#                                        place published  \
# 15 - Forest.json                                  None
# 12 - Farmland.json                                None
# 22 - Natural Pest Control.json                    None
# 3 - Primate.json                                  None
# 0 - Subtidal Benthic Invertebrate.json            None
#
#                                                        institution  \
# 15 - Forest.json                        Conservation Evidence Team
# 12 - Farmland.json                      Conservation Evidence Team
# 22 - Natural Pest Control.json          Conservation Evidence Team
# 3 - Primate.json                        Conservation Evidence Team
# 0 - Subtidal Benthic Invertebrate.json  Conservation Evidence Team
#
#                                                     publisher  date  doi  \
# 15 - Forest.json                        Conservation Evidence  None  NaN
# 12 - Farmland.json                      Conservation Evidence  None  NaN
# 22 - Natural Pest Control.json          Conservation Evidence  None  NaN
# 3 - Primate.json                        Conservation Evidence  None  NaN
# 0 - Subtidal Benthic Invertebrate.json  Conservation Evidence  None  NaN
#
#                                                        class  abstract  \
# 15 - Forest.json                                     Forests       NaN
# 12 - Farmland.json                                  Farmland       NaN
# 22 - Natural Pest Control.json                         Pests       NaN
# 3 - Primate.json                                     Mammals       NaN
# 0 - Subtidal Benthic Invertebrate.json  Marine Invertebrates       NaN
#
#                                                                                       url  \
# 15 - Forest.json                        https://www.conservationevidence.com/synopsis/...
# 12 - Farmland.json                      https://www.conservationevidence.com/synopsis/...
# 22 - Natural Pest Control.json          https://www.conservationevidence.com/synopsis/...
# 3 - Primate.json                        https://www.conservationevidence.com/synopsis/...
# 0 - Subtidal Benthic Invertebrate.json  https://www.conservationevidence.com/synopsis/...
#
#                                                                                      text  \
# 15 - Forest.json                        Forest\nConservation\nGlobal evidence for the ...
# 12 - Farmland.json                      Farmland  \nConservation \nEvidence for the ef...
# 22 - Natural Pest Control.json          1 \n \n \n \nENHANCING NATURAL PEST \nCONTROL ...
# 3 - Primate.json                         \n \n \nii \n \n \n \n \n \n \n  \nPrimate Co...
# 0 - Subtidal Benthic Invertebrate.json  1 \n \n \n2 \n \n \nSubtidal Benthic Invertebr...
#
#                                        report number folder
# 15 - Forest.json                                 NaN    NaN
# 12 - Farmland.json                               NaN    NaN
# 22 - Natural Pest Control.json                   NaN    NaN
# 3 - Primate.json                                 NaN    NaN
# 0 - Subtidal Benthic Invertebrate.json           NaN    NaN

# %%
# filter down and drop unknown classes
write_data = data[['url','text','class']].dropna(subset=['class'])
write_data.head()
# Out:
#                                                                                       url  \
# 15 - Forest.json                        https://www.conservationevidence.com/synopsis/...
# 12 - Farmland.json                      https://www.conservationevidence.com/synopsis/...
# 22 - Natural Pest Control.json          https://www.conservationevidence.com/synopsis/...
# 3 - Primate.json                        https://www.conservationevidence.com/synopsis/...
# 0 - Subtidal Benthic Invertebrate.json  https://www.conservationevidence.com/synopsis/...
#
#                                                                                      text  \
# 15 - Forest.json                        Forest\nConservation\nGlobal evidence for the ...
# 12 - Farmland.json                      Farmland  \nConservation \nEvidence for the ef...
# 22 - Natural Pest Control.json          1 \n \n \n \nENHANCING NATURAL PEST \nCONTROL ...
# 3 - Primate.json                         \n \n \nii \n \n \n \n \n \n \n  \nPrimate Co...
# 0 - Subtidal Benthic Invertebrate.json  1 \n \n \n2 \n \n \nSubtidal Benthic Invertebr...
#
#                                                        class
# 15 - Forest.json                                     Forests
# 12 - Farmland.json                                  Farmland
# 22 - Natural Pest Control.json                         Pests
# 3 - Primate.json                                     Mammals
# 0 - Subtidal Benthic Invertebrate.json  Marine Invertebrates

# %%
write_data.to_json('../../data/labelled/relevant.json',orient='records')

# %%
def merge_data():
    relevant = pd.read_json('../../data/labelled/relevant.json',orient='records')
    irrelevant = pd.read_json('../../data/labelled/irrelevant.json',orient='records')
    data = pd.concat([relevant,irrelevant])
    return data

merged_data = merge_data()
print(merged_data.info())
merged_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9520 entries, 0 to 2131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     9520 non-null   object
#  1   text    9520 non-null   object
#  2   class   9520 non-null   object
# dtypes: object(3)
# memory usage: 297.5+ KB
# None
#                                                  url  \
# 0  https://www.conservationevidence.com/synopsis/...
# 1  https://www.conservationevidence.com/synopsis/...
# 2  https://www.conservationevidence.com/synopsis/...
# 3  https://www.conservationevidence.com/synopsis/...
# 4  https://www.conservationevidence.com/synopsis/...
#
#                                                 text                 class
# 0  Forest\nConservation\nGlobal evidence for the ...               Forests
# 1  Farmland  \nConservation \nEvidence for the ef...              Farmland
# 2  1 \n \n \n \nENHANCING NATURAL PEST \nCONTROL ...                 Pests
# 3   \n \n \nii \n \n \n \n \n \n \n  \nPrimate Co...               Mammals
# 4  1 \n \n \n2 \n \n \nSubtidal Benthic Invertebr...  Marine Invertebrates

# %%
merged_data.to_json('../../data/labelled/data.json',orient='records')
