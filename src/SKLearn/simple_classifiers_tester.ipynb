# %%
import pandas as pd
from tqdm.auto import tqdm

# %%
def import_labelled_data(path="data/level-0.5/data.json"):
    data = pd.read_json(path, encoding="latin-1")
    return data



print("Loading data...")

test_dataset = import_labelled_data(path="../../data/level-0.5/irrelevant.json", )

print("Data loaded.")


test_dataset = test_dataset.sample(5000)

test_dataset = test_dataset.sample(frac=1).reset_index(drop=True)


test_dataset.info()
test_dataset.head()
# Out:
# Loading data...
# Data loaded.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           5000 non-null   object
#  1   text          5000 non-null   object
#  2   relevance     5000 non-null   object
#  3   multiclasses  5000 non-null   object
# dtypes: object(4)
# memory usage: 156.4+ KB
#                                                  url  \
# 0  https://worldoutreach.org/study_guides/abiding...
# 1  https://zahp.org/wp-content/uploads/2020/10/On...
# 2  https://www.yatsandiego.org/_files/ugd/30dc38_...
# 3  https://www.deped.gov.ph/wp-content/uploads/20...
# 4  https://repositorio.upla.edu.pe/bitstream/hand...
#
#                                                 text   relevance multiclasses
# 0  prospered. We must stay connected! We must all...  irrelevant           []
# 1  One Health Investigation Form – Animals with S...  irrelevant           []
# 2  Young Actors' Theatre ENCORE! Theatre Spring V...  irrelevant           []
# 3  --"'i::.,% t"H"t Argutlir of Or ?bitiprinar De...  irrelevant           []
# 4  i UNIVERSIDAD PERUANA LOS ANDES Facultad de Ci...  irrelevant           []

# %%
from pickle import load

with open('models/LogisticRegression.pkl', 'rb') as file:
    classifier = load(file)

# %%
probabilities = classifier.predict_proba(test_dataset)[:,1]
test_dataset['score'] = probabilities
test_dataset['prediction'] = (test_dataset['score'] > 0.5).apply(lambda x:'relevant' if x else 'irrelevant')

test_dataset = test_dataset.sort_values(by='score', ascending=False)

# %%
test_dataset.head()
# Out:
#                                                     url  \
# 2540  https://digitalarchive.worldfishcenter.org/bit...
# 4692  http://www.wpcouncil.org/wp-content/uploads/20...
# 705   https://zooreach.org/downloads/ZOO_CAMP_PHVA_r...
# 4355  https://dcprime.com/wp-content/uploads/2019/12...
# 4670  https://wwjournal.org/wp-content/uploads/sites...
#
#                                                    text   relevance  \
# 2540  MARINE ECOLOGY PROGRESS SERIES Vol. 588: 85–10...  irrelevant
# 4692  2021 Quantitative estimates of post-release su...  irrelevant
# 705   THE STATUS AND DISTRIBUTION OF REPTILES IN THE...  irrelevant
# 4355  Durable Responses and Survival in High Risk AM...  irrelevant
# 4670  Western Wildlife 11:11–18 • 2024 Submitted: 18...  irrelevant
#
#      multiclasses     score prediction
# 2540           []  0.769283   relevant
# 4692           []  0.641948   relevant
# 705            []  0.632248   relevant
# 4355           []  0.596535   relevant
# 4670           []  0.577482   relevant

# %%
with pd.option_context('display.max_colwidth', 100):
    display(test_dataset[['url', 'score', 'prediction']].head(10))
    display(test_dataset['url'].head(10))
# Out:
#                                                                                                       url  \
# 2540  https://digitalarchive.worldfishcenter.org/bitstream/handle/20.500.12348/692/4226.pdf?sequence=1...
# 4692                  http://www.wpcouncil.org/wp-content/uploads/2020/11/08.C1-Hutchinson-et-al-2021.pdf
# 705                          https://zooreach.org/downloads/ZOO_CAMP_PHVA_reports/2014-Reptile-Report.pdf
# 4355                          https://dcprime.com/wp-content/uploads/2019/12/Poster-1381-Luca-Janssen.pdf
# 4670                        https://wwjournal.org/wp-content/uploads/sites/9/2024/06/Roy_etal_WW_2024.pdf
# 4300                               https://wos.org/documents/Publications/WA%20Birds/2006/wabirds2006.pdf
# 670   http://wiki.daz3d.com/lib/exe/fetch.php/public/read_me/index/16122/16122_songbirdremixvultures2.pdf
# 4542  https://www.xerces.org/sites/default/files/2018-05/17-040_01_ProtectingCaliforniaButterflyGroves...
# 4382                                      https://zenodo.org/records/1234577/files/article.pdf?download=1
# 2364  https://www.wrmp.org/wp-content/uploads/2023/03/WRMP-Priority-Monitoring-Site-Networks_2023-0125...
#
#          score  prediction
# 2540  0.769283    relevant
# 4692  0.641948    relevant
# 705   0.632248    relevant
# 4355  0.596535    relevant
# 4670  0.577482    relevant
# 4300  0.566805    relevant
# 670   0.505714    relevant
# 4542  0.497060  irrelevant
# 4382  0.477264  irrelevant
# 2364  0.442243  irrelevant
# 2540    https://digitalarchive.worldfishcenter.org/bitstream/handle/20.500.12348/692/4226.pdf?sequence=1...
# 4692                    http://www.wpcouncil.org/wp-content/uploads/2020/11/08.C1-Hutchinson-et-al-2021.pdf
# 705                            https://zooreach.org/downloads/ZOO_CAMP_PHVA_reports/2014-Reptile-Report.pdf
# 4355                            https://dcprime.com/wp-content/uploads/2019/12/Poster-1381-Luca-Janssen.pdf
# 4670                          https://wwjournal.org/wp-content/uploads/sites/9/2024/06/Roy_etal_WW_2024.pdf
# 4300                                 https://wos.org/documents/Publications/WA%20Birds/2006/wabirds2006.pdf
# 670     http://wiki.daz3d.com/lib/exe/fetch.php/public/read_me/index/16122/16122_songbirdremixvultures2.pdf
# 4542    https://www.xerces.org/sites/default/files/2018-05/17-040_01_ProtectingCaliforniaButterflyGroves...
# 4382                                        https://zenodo.org/records/1234577/files/article.pdf?download=1
# 2364    https://www.wrmp.org/wp-content/uploads/2023/03/WRMP-Priority-Monitoring-Site-Networks_2023-0125...
# Name: url, dtype: object
