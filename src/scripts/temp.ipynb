# %%
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm, trange

# %%
link = 'https://www.conservationevidence.com/data/studies?terms=&sort=created_at#searchcontainer'
response = requests.get(link)
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]>
# <html id="ie6">
# <![endif]-->
# <!--[if IE 7]>
# <html id="ie7">
# <![endif]-->
# <!--[if IE 8]>
# <html id="ie8">
# <![endif]-->
# <!--[if !(IE 6) | !(IE 7) | !(IE 8)  ]>
# <html>
# <!--<![endif]-->
# <head>
#  <!-- META AND OPEN GRAPH -->
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#  <link href="/assets/27087050/css/cms.css" rel="stylesheet" type="text/css"/>
#  <link href="/assets/2f77d0f8/listview/styles.css" rel="stylesheet" type="text/css"/>
#  <link href="/assets/8396e448/pager.css" rel="stylesheet" type="text/css"/>
#  <link href="/css/jquery-ui.css?ver=12112020" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/assets-frontend-rebuild/css/style.min.css?ver=12112020" media="screen" rel="stylesheet" type="text/css"/>
#  <script src="/assets/a7802aaf/jquery.js" type="text/javascript">
#  </script>
#  <script src="/assets/a7802aaf/jquery.ba-bbq.js" type="text/javascript">
#  </script>
#  <script src="/js/html5shiv.js" type="text/javascript">
#  </script>
#  <script src="/js/coev/main.js?ver=12112020" type="text/javascript">
#  </script>
#  <script src="/js/category.js" type="text/javascript">
#  </script>
#  <script src="/assets-frontend-rebuild/js/libs/bootstrap.min.js?ver=12112020" type="text/javascript">
#  </script>
#  <script src="/assets-frontend-rebuild/js/script.min.js?ver=12112020" type="text/javascript">
#  </script>
#  <script src="/assets-frontend-rebuild/js/libs/jquery.min.js?ver=12112020" type="text/javascript">
#  </script>
#  <script src="/js/jquery-ui.js?ver=12112020" type="text/javascript">
#  </script>
#  <title>
#   Conservation Evidence: Evidence Data
#  </title>
#  <meta content="Conservation Evidence: Evidence Data" property="og:title"/>
#  <meta content="website" property="og:type"/>
#  <meta content="/../assets-frontend-rebuild/images/preview-image.jpg" property="og:image">
#   <meta content="Conservation Evidence" property="og:site_name">
#    <!-- DataTables -->
#    <link href="https://cdn.datatables.net/v/dt/dt-1.10.15/datatables.min.css" rel="stylesheet" type="text/css"/>
#    <script src="https://cdn.datatables.net/v/dt/dt-1.10.15/datatables.min.js" type="text/javascript">
#    </script>
#    <link href="https://use.typekit.net/bpc6muy.css" rel="stylesheet"/>
#    <!-- CSS -->
#    <!--[if lte IE 8]><link rel="stylesheet" type="text/css" href="/css/ie.css"><![endif]-->
#    <!--[if IE 7]><link rel="stylesheet" type="text/css" href="/css/ie7.css"><![endif]-->
#    <!-- JS -->
#    <!-- FAVICON -->
#    <link href="/../assets-frontend-rebuild/images/ce.ico" rel="shortcut icon">
#     <script type="text/javascript">
#      // Function to dynamically load the Google Translate script
#         function loadGoogleTranslate() {
#             var googleTranslateScript = document.createElement('script');
#             googleTranslateScript.type = 'text/javascript';
#             googleTranslateScript.src = 'https://translate.google.com/translate_a/element.js?cb=googleTranslateElementInit';
#             document.getElementsByTagName('head')[0].appendChild(googleTranslateScript);
#         }
#
#         // Callback function for Google Translate script
#         function googleTranslateElementInit() {
#             new google.translate.TranslateElement({
#                 pageLanguage: 'en',
#                 layout: google.translate.TranslateElement.InlineLayout.SIMPLE
#             }, 'google_translate_element');
#         }
#
#         // Load the Google Translate script when the DOM is fully loaded
#         document.addEventListener('DOMContentLoaded', function () {
#             loadGoogleTranslate();
#         });
#     </script>
#    </link>
#   </meta>
#  </meta>
# </head>
# <body class="">
#  <!--  Facebook API integration  -->
#  <div id="fb-root">
#  </div>
#  <script>
#   (function(d, s, id) {
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_GB/sdk.js#xfbml=1&version=v2.9";
#       fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
#  </script>
#  <!-- IE6 Upgrade message !-->
#  <!--[if lte IE 6]><script src="includes/ie6/warning.js"></script><script>window.onload=function(){e("includes/ie6/")}</script><![endif]-->
#  <!-- Header start here -->
#  <!-- Go to Dashboard link -->
#  <div>
#  </div>
#  <header>
#   <div class="container">
#    <div class="row header-row">
#     <div class="col-10 col-lg-4 header-logo">
#      <a href="/">
#       <img alt="Logo" src="/../assets-frontend-rebuild/images/logo.svg"/>
#      </a>
#     </div>
#     <div aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="col-2 burger-menu collapsed" data-target="#navbarSupportedContent" data-toggle="collapse">
#      <span class="bar1">
#      </span>
#      <span class="bar2">
#      </span>
#      <span class="bar3">
#      </span>
#     </div>
#     <div class="col-lg-8 header-menus collapse" id="navbarSupportedContent">
#      <div class="row">
#       <div class="header-menus-content-wrapper">
#        <div class="col-12 header--top text-lg-right">
#         <ul class="list-unstyled mb-0">
#          <li class="list-inline-item">
#           <a href="/content/page/79">
#            Assessing the evidence
#           </a>
#          </li>
#          <li class="list-inline-item">
#           <a href="/content/page/24">
#            About us
#           </a>
#          </li>
#          <li class="list-inline-item">
#           <a href="/faq/index">
#            Help
#           </a>
#          </li>
#         </ul>
#         <div id="google_translate_element">
#         </div>
#        </div>
#        <div class="col-12 header--bottom">
#         <!-- Search Form - Mobile case - Starts-->
#         <div class="d-lg-none header-search">
#          <!-- Hide mobile navigation search box on synopses page -->
#          <div class="search-box--upper">
#           <div class="container">
#            <div class="row">
#             <div class="col-12">
#              <div class="search-box">
#               <!-- Search form -->
#               <form class="form-inline">
#                <div class="search-box__icon">
#                 <form action="/data/index" method="get">
#                  <input autocomplete="off" class="form-control form-control--custom" id="mobileterms" name="mobileterms" placeholder="Search key word or species" type="text" value=""/>
#                  <span class="search-go-wrapper green-search-icon">
#                   <input id="mobilesearchgo" name="yt1" type="submit" value=""/>
#                  </span>
#                 </form>
#                </div>
#               </form>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- Search Form - Mobile case - Ends-->
#         <div class="header-nav">
#          <ul class="text-uppercase list-unstyled mb-0">
#           <!-- adding active class on -->
#           <li class="list-inline-item active">
#            <a href="/data/studies">
#             <span>
#              Studies
#             </span>
#            </a>
#           </li>
#           <li class="list-inline-item">
#            <a href="/data/index">
#             <span>
#              Actions
#             </span>
#            </a>
#           </li>
#           <li class="list-inline-item">
#            <a href="/synopsis/index">
#             <span>
#              Synopses
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="header-button">
#          <a class="button button--green" href="https://conservationevidencejournal.com/">
#           CE Journal
#           <i class="fal fa-chevron-right">
#           </i>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </header>
#  <!-- Header end here -->
#  <section class="clearfix" id="middle">
#   <section id="content">
#    <!-- search form -->
#    <div class="search-box--upper">
#     <div class="container">
#      <div class="row">
#       <div class="col-12">
#        <div class="search-box">
#         <!-- Updates the search box placeholder as per the current page (Studies/Action) -->
#         <!-- Search form -->
#         <form class="form-inline">
#          <div class="search-box__icon">
#           <form action="/data/index" method="get">
#            <input autocomplete="off" class="form-control form-control--custom" id="terms" name="terms" placeholder="Search Studies by keyword or species" type="text" value=""/>
#            <span class="search-go-wrapper green-search-icon">
#             <input id="searchgo" name="yt2" type="submit" value=""/>
#            </span>
#           </form>
#          </div>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- hero banner starts here -->
#    <div class="hero-banner hero-banner--actions" style="background-image:url('../assets-frontend-rebuild/images/studies-banner.jpg')">
#     <figure class="d-lg-none" style="background-image:url('../assets-frontend-rebuild/images/studies-banner.jpg')">
#     </figure>
#     <div class="container">
#      <div class="row">
#       <div class="col-12">
#        <div class="hero-banner--content">
#         <span class="total-actions">
#          <strong>
#           8663
#          </strong>
#          Studies found
#         </span>
#         <h2>
#          Studies
#         </h2>
#         <p>
#          An individual study is a summary of a specific scientific study, providing background context, the conservation action(s) taken and their consequences.
#         </p>
#         <p>
#          Review the associated
#          <u>
#           <a href="/data/index?terms=&amp;sort=created_at">
#            Actions
#           </a>
#          </u>
#         </p>
#         <div class="d-lg-flex justify-space-between">
#          <a class="button button--link" href="/content/page/104">
#           About studies
#          </a>
#          <a class="button button--link" href="/content/page/108">
#           Sources of evidence
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- hero banner ends here -->
#    <!-- <section class="actions-found">
#
#     <h2 class="study-count">Individual Studies</h2>
#     <p>Can't find what you're looking for? <a href="/data/index?">You can also search Actions.</a></p>
#     <p><span class="not-sure">Not sure what Individual Studies are?</span> <a href="/data/#data_explained_modal" data-toggle="modal">Read a brief description.</a></p>
#
# </section> -->
#    <section class="faded notindex d-none" id="searchbox">
#     <form action="/data/index" method="get">
#      <h1>
#       Search for evidence
#      </h1>
#      <span class="suggestion">
#       <div class="cms node-block">
#        <div class="node-content">
#         <p>
#          e.g. "frogs chytrid"
#         </p>
#        </div>
#       </div>
#      </span>
#      <div id="searchinput">
#       <input id="searchterms" name="terms" title="Search our evidence" type="text" value=""/>
#       <input id="searchgo" name="yt0" type="submit" value="Search"/>
#      </div>
#      <div class="expandable" id="searchmore">
#       <a class="title" href="">
#        More options
#       </a>
#       <a href="/data/index" id="browseall">
#        Browse all evidence
#       </a>
#       <a href="/data/advanced" id="advancedsearch">
#        Advanced search
#       </a>
#       <a href="/history/index" id="searchhistory">
#        Search history and saved searches
#       </a>
#       <div class="expanded">
#        <div class="col1">
#         <label for="action">
#          Action
#         </label>
#         <select id="action_type_id" name="action_type_id[]">
#          <option value="">
#           All actions
#          </option>
#          <option value="4">
#           Education and awareness
#          </option>
#          <option value="2">
#           Land/water management
#          </option>
#          <option value="1">
#           Land/water protection
#          </option>
#          <option value="5">
#           Law &amp; policy
#          </option>
#          <option value="6">
#           Livelihood, economic &amp; other incentives
#          </option>
#          <option value="7">
#           Other
#          </option>
#          <option value="3">
#           Species management
#          </option>
#         </select>
#         <label for="continent">
#          Threat
#         </label>
#         <select id="threat_type_id" name="threat_type_id[]">
#          <option value="">
#           All threat
#          </option>
#          <option value="2">
#           Agriculture &amp; aquaculture
#          </option>
#          <option value="6">
#           Biological resource use
#          </option>
#          <option value="12">
#           Climate change &amp; severe weather
#          </option>
#          <option value="4">
#           Energy production &amp; mining
#          </option>
#          <option value="11">
#           Geological events
#          </option>
#          <option value="7">
#           Human intrusions &amp; disturbance
#          </option>
#          <option value="9">
#           Invasive &amp; other problematic species &amp; genes
#          </option>
#          <option value="8">
#           Natural system modifications
#          </option>
#          <option value="13">
#           Other
#          </option>
#          <option value="10">
#           Pollution
#          </option>
#          <option value="1">
#           Residential &amp; commercial development
#          </option>
#          <option value="5">
#           Transportation &amp; service corridors
#          </option>
#         </select>
#        </div>
#        <div class="col2">
#         <label for="habitat">
#          Habitat
#         </label>
#         <select id="habitat_type_id" name="habitat_type_id[]">
#          <option value="">
#           All habitats
#          </option>
#          <option value="12">
#           Artificial Habitats
#          </option>
#          <option value="11">
#           Coastal
#          </option>
#          <option value="6">
#           Desert
#          </option>
#          <option value="1">
#           Forest &amp; Woodland
#          </option>
#          <option value="4">
#           Grassland
#          </option>
#          <option value="10">
#           Marine
#          </option>
#          <option value="13">
#           Other
#          </option>
#          <option value="7">
#           Rivers, Streams, Creeks
#          </option>
#          <option value="5">
#           Rocky Habitats &amp; Caves
#          </option>
#          <option value="2">
#           Savanna
#          </option>
#          <option value="3">
#           Shrubland
#          </option>
#          <option value="8">
#           Wetlands
#          </option>
#         </select>
#         <label for="habitat">
#          Broad
#         </label>
#         <select id="broad_id" name="broad_id[]">
#          <option value="">
#           All taxa
#          </option>
#          <option value="7">
#           Amphibians
#          </option>
#          <option value="14">
#           Bats
#          </option>
#          <option value="1">
#           Bees
#          </option>
#          <option value="2">
#           Birds
#          </option>
#          <option value="11">
#           Crop plants
#          </option>
#          <option value="10">
#           Diseases
#          </option>
#          <option value="6">
#           Fish
#          </option>
#          <option value="16">
#           Forest
#          </option>
#          <option value="15">
#           Freshwater Invasive Species
#          </option>
#          <option value="13">
#           Fungi
#          </option>
#          <option value="20">
#           Grassland
#          </option>
#          <option value="4">
#           Invasive plants
#          </option>
#          <option value="5">
#           Invertebrates
#          </option>
#          <option value="12">
#           Livestock
#          </option>
#          <option value="9">
#           Mammals
#          </option>
#          <option value="21">
#           Marine
#          </option>
#          <option value="19">
#           Marine Invertebrates
#          </option>
#          <option value="3">
#           Plants
#          </option>
#          <option value="8">
#           Reptiles
#          </option>
#          <option value="18">
#           Shrublands and heathlands
#          </option>
#          <option value="17">
#           Wetlands
#          </option>
#         </select>
#        </div>
#        <div class="col3">
#         <label for="continent">
#          Continent of study
#         </label>
#         <select id="continent_id" name="continent_id[]">
#          <option value="">
#           All continents
#          </option>
#          <option value="1">
#           Africa
#          </option>
#          <option value="2">
#           Americas
#          </option>
#          <option value="3">
#           Antarctic
#          </option>
#          <option value="4">
#           Asia
#          </option>
#          <option value="5">
#           Europe
#          </option>
#          <option value="6">
#           Oceania
#          </option>
#         </select>
#         <label for="continent">
#          Country of study
#         </label>
#         <select id="country_id" name="country_id[]">
#          <option value="">
#           All countries
#          </option>
#          <option value="112">
#           Afghanistan
#          </option>
#          <option value="401">
#           Aland Islands
#          </option>
#          <option value="157">
#           Albania
#          </option>
#          <option value="1">
#           Algeria
#          </option>
#          <option value="207">
#           American Samoa
#          </option>
#          <option value="158">
#           Andorra
#          </option>
#          <option value="2">
#           Angola
#          </option>
#          <option value="58">
#           Anguilla
#          </option>
#          <option value="398">
#           Antarctica
#          </option>
#          <option value="59">
#           Antigua and Barbuda
#          </option>
#          <option value="60">
#           Argentina
#          </option>
#          <option value="159">
#           Armenia
#          </option>
#          <option value="61">
#           Aruba
#          </option>
#          <option value="3">
#           Ascension
#          </option>
#          <option value="208">
#           Australia
#          </option>
#          <option value="160">
#           Austria
#          </option>
#          <option value="161">
#           Azerbaijan
#          </option>
#          <option value="62">
#           Bahamas
#          </option>
#          <option value="113">
#           Bahrain
#          </option>
#          <option value="114">
#           Bangladesh
#          </option>
#          <option value="63">
#           Barbados
#          </option>
#          <option value="162">
#           Belarus
#          </option>
#          <option value="163">
#           Belgium
#          </option>
#          <option value="64">
#           Belize
#          </option>
#          <option value="4">
#           Benin
#          </option>
#          <option value="65">
#           Bermuda
#          </option>
#          <option value="115">
#           Bhutan
#          </option>
#          <option value="66">
#           Bolivia
#          </option>
#          <option value="164">
#           Bosnia and Herzegovina
#          </option>
#          <option value="5">
#           Botswana
#          </option>
#          <option value="67">
#           Brazil
#          </option>
#          <option value="68">
#           British Virgin Islands
#          </option>
#          <option value="116">
#           Brunei
#          </option>
#          <option value="165">
#           Bulgaria
#          </option>
#          <option value="6">
#           Burkina Faso
#          </option>
#          <option value="7">
#           Burundi
#          </option>
#          <option value="117">
#           Cambodia
#          </option>
#          <option value="8">
#           Cameroon
#          </option>
#          <option value="69">
#           Canada
#          </option>
#          <option value="9">
#           Cape Verde
#          </option>
#          <option value="70">
#           Cayman Islands
#          </option>
#          <option value="10">
#           Central African Republic
#          </option>
#          <option value="11">
#           Chad
#          </option>
#          <option value="71">
#           Chile
#          </option>
#          <option value="118">
#           China, P.R.
#          </option>
#          <option value="72">
#           Colombia
#          </option>
#          <option value="12">
#           Comoros
#          </option>
#          <option value="13">
#           Congo (Brazzaville)
#          </option>
#          <option value="209">
#           Cook Islands
#          </option>
#          <option value="73">
#           Costa Rica
#          </option>
#          <option value="166">
#           Croatia
#          </option>
#          <option value="74">
#           Cuba
#          </option>
#          <option value="167">
#           Cyprus
#          </option>
#          <option value="168">
#           Czech Republic
#          </option>
#          <option value="15">
#           Democratic Republic of the Congo
#          </option>
#          <option value="169">
#           Denmark
#          </option>
#          <option value="16">
#           Djibouti
#          </option>
#          <option value="75">
#           Dominica
#          </option>
#          <option value="76">
#           Dominican Republic
#          </option>
#          <option value="119">
#           East Timor
#          </option>
#          <option value="77">
#           Ecuador
#          </option>
#          <option value="17">
#           Egypt
#          </option>
#          <option value="78">
#           El Salvador
#          </option>
#          <option value="18">
#           Equatorial Guinea
#          </option>
#          <option value="19">
#           Eritrea
#          </option>
#          <option value="170">
#           Estonia
#          </option>
#          <option value="20">
#           Ethiopia
#          </option>
#          <option value="79">
#           Falkland Islands
#          </option>
#          <option value="171">
#           Faroe Islands
#          </option>
#          <option value="210">
#           Fiji
#          </option>
#          <option value="172">
#           Finland
#          </option>
#          <option value="173">
#           France
#          </option>
#          <option value="80">
#           French Guyana
#          </option>
#          <option value="211">
#           French Polynesia
#          </option>
#          <option value="81">
#           French West Indies
#          </option>
#          <option value="21">
#           Gabon
#          </option>
#          <option value="22">
#           Gambia, The
#          </option>
#          <option value="174">
#           Georgia
#          </option>
#          <option value="175">
#           Germany
#          </option>
#          <option value="23">
#           Ghana
#          </option>
#          <option value="176">
#           Gibralter
#          </option>
#          <option value="177">
#           Greece
#          </option>
#          <option value="82">
#           Greenland
#          </option>
#          <option value="83">
#           Grenada
#          </option>
#          <option value="84">
#           Guadeloupe
#          </option>
#          <option value="212">
#           Guam
#          </option>
#          <option value="85">
#           Guatemala
#          </option>
#          <option value="24">
#           Guinea
#          </option>
#          <option value="25">
#           Guinea-Bissau
#          </option>
#          <option value="86">
#           Guyana
#          </option>
#          <option value="87">
#           Haiti
#          </option>
#          <option value="88">
#           Honduras
#          </option>
#          <option value="178">
#           Hungary
#          </option>
#          <option value="179">
#           Iceland
#          </option>
#          <option value="120">
#           India
#          </option>
#          <option value="121">
#           Indonesia
#          </option>
#          <option value="122">
#           Iran
#          </option>
#          <option value="123">
#           Iraq
#          </option>
#          <option value="366">
#           Ireland
#          </option>
#          <option value="180">
#           Ireland (Eire)
#          </option>
#          <option value="124">
#           Israel
#          </option>
#          <option value="181">
#           Italy
#          </option>
#          <option value="14">
#           Ivory Coast
#          </option>
#          <option value="89">
#           Jamaica
#          </option>
#          <option value="125">
#           Japan
#          </option>
#          <option value="126">
#           Jordan
#          </option>
#          <option value="127">
#           Kazakhstan
#          </option>
#          <option value="26">
#           Kenya
#          </option>
#          <option value="213">
#           Kiribati (Tarawa &amp; Christmas Islands)
#          </option>
#          <option value="128">
#           Kuwait
#          </option>
#          <option value="129">
#           Kyrgyzstan (Kyrgyzia)
#          </option>
#          <option value="130">
#           Laos
#          </option>
#          <option value="182">
#           Latvia
#          </option>
#          <option value="131">
#           Lebanon
#          </option>
#          <option value="27">
#           Lesotho
#          </option>
#          <option value="28">
#           Liberia
#          </option>
#          <option value="29">
#           Libya
#          </option>
#          <option value="183">
#           Liechtenstein
#          </option>
#          <option value="184">
#           Lithuania
#          </option>
#          <option value="185">
#           Luxembourg
#          </option>
#          <option value="186">
#           Macedonia, FYR
#          </option>
#          <option value="30">
#           Madagascar
#          </option>
#          <option value="31">
#           Malawi
#          </option>
#          <option value="132">
#           Malaysia
#          </option>
#          <option value="133">
#           Maldives
#          </option>
#          <option value="32">
#           Mali
#          </option>
#          <option value="187">
#           Malta
#          </option>
#          <option value="214">
#           Marshall Islands
#          </option>
#          <option value="90">
#           Martinique
#          </option>
#          <option value="33">
#           Mauritania
#          </option>
#          <option value="34">
#           Mauritius
#          </option>
#          <option value="91">
#           Mexico
#          </option>
#          <option value="215">
#           Micronesia, Federated States of
#          </option>
#          <option value="188">
#           Moldova
#          </option>
#          <option value="189">
#           Monaco
#          </option>
#          <option value="134">
#           Mongolia
#          </option>
#          <option value="92">
#           Montserrat
#          </option>
#          <option value="35">
#           Morocco
#          </option>
#          <option value="36">
#           Mozambique
#          </option>
#          <option value="135">
#           Myanmar [Burma]
#          </option>
#          <option value="37">
#           Namibia
#          </option>
#          <option value="136">
#           Nepal
#          </option>
#          <option value="93">
#           Netherland Antilles
#          </option>
#          <option value="190">
#           Netherlands
#          </option>
#          <option value="216">
#           New Caledonia
#          </option>
#          <option value="217">
#           New Zealand
#          </option>
#          <option value="94">
#           Nicaragua
#          </option>
#          <option value="38">
#           Niger
#          </option>
#          <option value="39">
#           Nigeria
#          </option>
#          <option value="218">
#           Niue
#          </option>
#          <option value="137">
#           North Korea
#          </option>
#          <option value="219">
#           Northern Marianas
#          </option>
#          <option value="191">
#           Norway
#          </option>
#          <option value="138">
#           Oman
#          </option>
#          <option value="140">
#           Pakistan
#          </option>
#          <option value="141">
#           Palastinian Auth.
#          </option>
#          <option value="95">
#           Panama
#          </option>
#          <option value="220">
#           Papua New Guinea
#          </option>
#          <option value="96">
#           Paraguay
#          </option>
#          <option value="97">
#           Peru
#          </option>
#          <option value="142">
#           Philippines
#          </option>
#          <option value="221">
#           Pitcairn
#          </option>
#          <option value="192">
#           Poland
#          </option>
#          <option value="193">
#           Portugal
#          </option>
#          <option value="98">
#           Puerto Rico
#          </option>
#          <option value="143">
#           Qatar
#          </option>
#          <option value="40">
#           Reunion
#          </option>
#          <option value="194">
#           Romania
#          </option>
#          <option value="402">
#           Russia
#          </option>
#          <option value="195">
#           Russian Federation
#          </option>
#          <option value="41">
#           Rwanda
#          </option>
#          <option value="222">
#           Samoa
#          </option>
#          <option value="196">
#           San Marino
#          </option>
#          <option value="42">
#           Sao Tome &amp; Principe
#          </option>
#          <option value="144">
#           Saudi Arabia
#          </option>
#          <option value="43">
#           Senegal
#          </option>
#          <option value="197">
#           Serbia &amp; Montenegro
#          </option>
#          <option value="44">
#           Seychelles
#          </option>
#          <option value="45">
#           Sierra Leone
#          </option>
#          <option value="145">
#           Singapore
#          </option>
#          <option value="198">
#           Slovakia
#          </option>
#          <option value="199">
#           Slovenia
#          </option>
#          <option value="223">
#           Solomon Islands
#          </option>
#          <option value="46">
#           Somalia
#          </option>
#          <option value="47">
#           South Africa
#          </option>
#          <option value="146">
#           South Korea
#          </option>
#          <option value="200">
#           Spain
#          </option>
#          <option value="147">
#           Sri Lanka
#          </option>
#          <option value="400">
#           St Helena
#          </option>
#          <option value="48">
#           St. Helena
#          </option>
#          <option value="99">
#           St. Kitts and Nevis
#          </option>
#          <option value="100">
#           St. Lucia
#          </option>
#          <option value="101">
#           St. Vincent &amp; The Grenadines
#          </option>
#          <option value="102">
#           St.Kitts
#          </option>
#          <option value="103">
#           St.Lucia
#          </option>
#          <option value="104">
#           St.Vincent
#          </option>
#          <option value="49">
#           Sudan
#          </option>
#          <option value="105">
#           Suriname
#          </option>
#          <option value="50">
#           Swaziland
#          </option>
#          <option value="201">
#           Sweden
#          </option>
#          <option value="202">
#           Switzerland
#          </option>
#          <option value="148">
#           Syria
#          </option>
#          <option value="149">
#           Taiwan
#          </option>
#          <option value="150">
#           Tajikistan
#          </option>
#          <option value="51">
#           Tanzania
#          </option>
#          <option value="151">
#           Thailand
#          </option>
#          <option value="399">
#           The Netherlands
#          </option>
#          <option value="52">
#           Togo
#          </option>
#          <option value="224">
#           Tonga
#          </option>
#          <option value="106">
#           Trinidad &amp; Tobago
#          </option>
#          <option value="53">
#           Tunisia
#          </option>
#          <option value="203">
#           Turkey
#          </option>
#          <option value="152">
#           Turkmenistan
#          </option>
#          <option value="107">
#           Turks &amp; Caicos
#          </option>
#          <option value="54">
#           Uganda
#          </option>
#          <option value="204">
#           Ukraine
#          </option>
#          <option value="153">
#           United Arab Emirates
#          </option>
#          <option value="205">
#           United Kingdom
#          </option>
#          <option value="108">
#           United States
#          </option>
#          <option value="109">
#           Uruguay
#          </option>
#          <option value="110">
#           US Virgin Islands
#          </option>
#          <option value="154">
#           Uzbekistan
#          </option>
#          <option value="225">
#           Vanuatu
#          </option>
#          <option value="206">
#           Vatican City
#          </option>
#          <option value="111">
#           Venezuela
#          </option>
#          <option value="155">
#           Vietnam
#          </option>
#          <option value="55">
#           Western Sahara
#          </option>
#          <option value="156">
#           Yemen
#          </option>
#          <option value="56">
#           Zambia
#          </option>
#          <option value="57">
#           Zimbabwe
#          </option>
#         </select>
#        </div>
#       </div>
#       <!--<input type="hidden" name="search" value="new">
#         <input type="hidden" name="type" value="standard">-->
#      </div>
#      <input name="new" type="hidden" value=""/>
#     </form>
#    </section>
#    <section class="category-listing" id="searchcontainer">
#     <div class="container">
#      <div class="row">
#       <section class="category-listing__wrapper">
#        <div aria-controls="refine" aria-expanded="false" aria-label="Filter Table" class="col-12 mobile-filter-table collapsed d-lg-none" data-target="#refine" data-toggle="collapse">
#         <div class="mobile-filter-table__wrapper">
#          <h4>
#           8663 Studies found
#          </h4>
#          <div>
#           <h5 class="refine-text">
#            Refine
#            <i class="fas fa-filter">
#            </i>
#           </h5>
#           <h5 class="hide-text">
#            Hide
#            <svg height="18px" version="1.1" viewbox="0 0 48 48" width="18px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#             <title>
#              Icons/Close
#             </title>
#             <g fill="none" fill-rule="evenodd" id="Icons/Close" stroke="none" stroke-width="1">
#              <path d="M4.41421356,1.58578644 L24.213,21.384 L44.0121933,1.58578644 C44.7932419,0.804737854 46.0595719,0.804737854 46.8406204,1.58578644 C47.621669,2.36683502 47.621669,3.63316498 46.8406204,4.41421356 L27.041,24.213 L46.8406204,44.0121933 C47.621669,44.7932419 47.621669,46.0595719 46.8406204,46.8406204 C46.0595719,47.621669 44.7932419,47.621669 44.0121933,46.8406204 L24.213,27.041 L4.41421356,46.8406204 C3.63316498,47.621669 2.36683502,47.621669 1.58578644,46.8406204 C0.804737854,46.0595719 0.804737854,44.7932419 1.58578644,44.0121933 L21.384,24.213 L1.58578644,4.41421356 C0.804737854,3.63316498 0.804737854,2.36683502 1.58578644,1.58578644 C2.36683502,0.804737854 3.63316498,0.804737854 4.41421356,1.58578644 Z" fill="#000000" id="Combined-Shape">
#              </path>
#             </g>
#            </svg>
#           </h5>
#          </div>
#         </div>
#        </div>
#        <div class="sidebar-container">
#         <aside class="refine active bordered-box navbar-collapse collapse" id="refine">
#          <form action="/data/studies#search-results" method="get">
#           <div class="category-listing__head">
#            <h4>
#             <strong>
#              Refine
#             </strong>
#            </h4>
#           </div>
#           <button class="go button button--with-icon button--with-icon_refresh" type="submit" value="Go">
#            Refresh results
#           </button>
#           <div class="content">
#            <div class="search-refine-interventions category-listing__items" style="display: none">
#             <h5 aria-controls="collapseOne" aria-expanded="false" class="collapsed" data-target="#collapseOne" data-toggle="collapse">
#              Category
#             </h5>
#             <div aria-labelledby="headingOne" class="collapse" data-parent="#accordionExample" id="collapseOne">
#              <ul class="list-inline">
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_8" title="Bird Conservation">
#                  Bird Conservation
#                  <input id="synopsis_id_8" name="synopsis_id[]" type="checkbox" value="8">
#                   <span>
#                   </span>
#                  </input>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_36" title="Terrestrial Mammal Conservation">
#                  Terrestrial Mammal Conservation
#                  <input id="synopsis_id_36" name="synopsis_id[]" type="checkbox" value="36"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_9" title="Farmland Conservation">
#                  Farmland Conservation
#                  <input id="synopsis_id_9" name="synopsis_id[]" type="checkbox" value="9"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_15" title="Reptile Conservation">
#                  Reptile Conservation
#                  <input id="synopsis_id_15" name="synopsis_id[]" type="checkbox" value="15"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_35" title="Marsh and Swamp Conservation">
#                  Marsh and Swamp Conservation
#                  <input id="synopsis_id_35" name="synopsis_id[]" type="checkbox" value="35"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_38" title="Marine Fish Conservation">
#                  Marine Fish Conservation
#                  <input id="synopsis_id_38" name="synopsis_id[]" type="checkbox" value="38"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_13" title="Amphibian Conservation">
#                  Amphibian Conservation
#                  <input id="synopsis_id_13" name="synopsis_id[]" type="checkbox" value="13"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_46" title="Butterfly and Moth Conservation">
#                  Butterfly and Moth Conservation
#                  <input id="synopsis_id_46" name="synopsis_id[]" type="checkbox" value="46"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_22" title="Mediterranean Farmland">
#                  Mediterranean Farmland
#                  <input id="synopsis_id_22" name="synopsis_id[]" type="checkbox" value="22"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_17" title="Forest Conservation">
#                  Forest Conservation
#                  <input id="synopsis_id_17" name="synopsis_id[]" type="checkbox" value="17"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_14" title="Bat Conservation">
#                  Bat Conservation
#                  <input id="synopsis_id_14" name="synopsis_id[]" type="checkbox" value="14"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_40" title="Subtidal Benthic Invertebrate Conservation">
#                  Subtidal Benthic Invertebrate Conservation
#                  <input id="synopsis_id_40" name="synopsis_id[]" type="checkbox" value="40"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_41" title="Marine and Freshwater Mammal Conservation">
#                  Marine and Freshwater Mammal Conservation
#                  <input id="synopsis_id_41" name="synopsis_id[]" type="checkbox" value="41"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_10" title="Natural Pest Control">
#                  Natural Pest Control
#                  <input id="synopsis_id_10" name="synopsis_id[]" type="checkbox" value="10"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_7" title="Bee Conservation">
#                  Bee Conservation
#                  <input id="synopsis_id_7" name="synopsis_id[]" type="checkbox" value="7"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_33" title="Peatland Conservation">
#                  Peatland Conservation
#                  <input id="synopsis_id_33" name="synopsis_id[]" type="checkbox" value="33"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_34" title="Shrubland and Heathland Conservation">
#                  Shrubland and Heathland Conservation
#                  <input id="synopsis_id_34" name="synopsis_id[]" type="checkbox" value="34"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_11" title="Soil Fertility">
#                  Soil Fertility
#                  <input id="synopsis_id_11" name="synopsis_id[]" type="checkbox" value="11"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_43" title="Grassland Conservation">
#                  Grassland Conservation
#                  <input id="synopsis_id_43" name="synopsis_id[]" type="checkbox" value="43"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_42" title="Cool Farm Biodiversity">
#                  Cool Farm Biodiversity
#                  <input id="synopsis_id_42" name="synopsis_id[]" type="checkbox" value="42"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_20" title="Management of Captive Animals">
#                  Management of Captive Animals
#                  <input id="synopsis_id_20" name="synopsis_id[]" type="checkbox" value="20"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_18" title="Control of Freshwater Invasive Species">
#                  Control of Freshwater Invasive Species
#                  <input id="synopsis_id_18" name="synopsis_id[]" type="checkbox" value="18"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_44" title="Biodiversity of Marine Artificial Structures">
#                  Biodiversity of Marine Artificial Structures
#                  <input id="synopsis_id_44" name="synopsis_id[]" type="checkbox" value="44"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_21" title="Primate Conservation">
#                  Primate Conservation
#                  <input id="synopsis_id_21" name="synopsis_id[]" type="checkbox" value="21"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_12" title="Sustainable Aquaculture">
#                  Sustainable Aquaculture
#                  <input id="synopsis_id_12" name="synopsis_id[]" type="checkbox" value="12"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_45" title="Coral Reef Conservation">
#                  Coral Reef Conservation
#                  <input id="synopsis_id_45" name="synopsis_id[]" type="checkbox" value="45"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="synopsis_id_30" title="All biodiversity">
#                  All biodiversity
#                  <input id="synopsis_id_30" name="synopsis_id[]" type="checkbox" value="30"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="search-refine-references category-listing__items" style="display: block">
#             <h5 aria-controls="collapseTwo" aria-expanded="false" class="collapsed" data-target="#collapseTwo" data-toggle="collapse">
#              Category
#             </h5>
#             <div aria-labelledby="headingOne" class="collapse" data-parent="#accordionExample" id="collapseTwo">
#              <ul class="list-inline">
#               <li>
#                <span class="ce-checkbox">
#                 <label for="broad_id_2" title="Birds">
#                  Birds
#                  <input id="broad_id_2" name="broad_id[]" type="checkbox" value="2"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="broad_id_9" title="Mammals">
#                  Mammals
#                  <input id="broad_id_9" name="broad_id[]" type="checkbox" value="9"/>
#                  <span>
#                  </span>
#                 </label>
#                </span>
#               </li>
#               <li>
#                <span class="ce-checkbox">
#                 <label for="broad_id_5" title="Invertebrates">
#                  Invertebrates
# ...
#     </h2>
#     <p>
#      An individual study is a summary of a specific scientific study, usually
#           taken from a scientific journal, but also from other resources such as
#           reports. It tells you the background context, the action(s) taken and
#           their consequences.
#     </p>
#     <p>
#      If you want more detail please look at the original reference.
#     </p>
#     <h2>
#      Actions
#     </h2>
#     <p>
#      Each action page focuses on a particular action you could take to benefit
#           wildlife or ecosystems.
#     </p>
#     <p>
#      It contains brief (150-200 word) descriptions of relevant studies (context,
#           action(s) taken and their consequences) and one or more key messages.
#     </p>
#     <p>
#      Key messages show the extent and main conclusions of the available evidence.
#           Using links within key messages, you can look at the paragraphs describing each
#           study to get more detail. Each paragraph allows you to assess the quality
#           of the evidence and how relevant it is to your situation.
#     </p>
#     <p>
#      Where we found no evidence, we have been unable to assess whether or not an intervention is effective or has any harmful impacts.
#     </p>
#    </div>
#   </div>
#  </section>
#  <!-- about conservation section starts here -->
#  <div class="about-conservation">
#   <div class="container">
#    <div class="row">
#     <!--  What Works in Conservation - Starts -->
#     <div class="col-lg-6 mb-lg-0 mb-4">
#      <div class="cms node-block">
#       <div class="node-content">
#        <div class="row">
#         <div class="col-sm-4">
#          <img alt="What Works 2021 cover" src="../../../../images//What_Works_2021_cover.png"/>
#         </div>
#         <div class="col-sm-8">
#          <div class="about-conservation__content">
#           <h3 class="h4">
#            What Works in Conservation
#           </h3>
#           <p>
#            <em>
#             What Works in Conservation
#            </em>
#            provides expert assessments of the effectiveness of actions, based on summarised evidence, in synopses. Subjects covered so far include amphibians, birds, mammals, forests, peatland and control of freshwater invasive species. More are in progress.
#           </p>
#           <p>
#            <a href="../../../../content/page/79" onclick="_gaq.push(['_trackEvent', 'PDFs', 'Download', 'What Works']);" rel="noopener" target="_blank">
#            </a>
#            More about
#            <u>
#             <a href="../../../../content/page/79" onclick="_gaq.push(['_trackEvent', 'PDFs', 'Download', 'What Works']);">
#              <em>
#               What Works in Conservation
#              </em>
#             </a>
#            </u>
#           </p>
#           <a class="button button--with-icon button--with-icon_redirects" href="https://www.openbookpublishers.com/product/1490" rel="noopener" target="_blank">
#            Download free PDF or purchase
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--  What Works in Conservation - Ends -->
#     <!-- Our Journal - Starts -->
#     <div class="col-lg-6 mb-lg-0 mb-4">
#      <div class="row">
#       <div class="col-sm-4">
#        <img alt="The Conservation Evidence Journal" src="../../../../images/our-journal.png"/>
#       </div>
#       <div class="col-sm-8">
#        <div class="about-conservation__content">
#         <h3 class="h4">
#          The Conservation Evidence Journal
#         </h3>
#         <div class="cms node-block">
#          <div class="node-content">
#           <p>
#            An online, free to publish in, open-access journal publishing results from research and projects that test the effectiveness of conservation actions.
#           </p>
#          </div>
#         </div>
#         <div class="latest-collection-block">
#          <p>
#           Read the latest volume:
#           <u>
#            <a href="/collection/54">
#             Volume 21
#            </a>
#           </u>
#          </p>
#          <!-- <h2>Virtual collections:</h2> -->
#         </div>
#         <a class="button" href="/collection/view">
#          Go to the CE Journal
#          <i class="fal fa-chevron-right">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Our Journal - Ends -->
#    </div>
#   </div>
#  </div>
#  <!-- about conservation section ends here -->
#  <!-- Newsletter/Twitter section starts here -->
#  <!-- Newsletter section starts here -->
#  <section class="newsletter_wrapper">
#   <div class="container">
#    <div class="row">
#     <!-- Twitter section -->
#     <!-- <div class="col-lg-5">
#                 <a class="twitter-timeline" href="https://twitter.com/ConservEvidence?ref_src=twsrc%5Etfw" data-width="450" data-height="600" data-theme="light" data-link-color="#619948">Tweets by ConservEvidence</a>
#                 <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#             </div> -->
#     <!-- Newsletter section -->
#     <div class="col-lg-12" id="newsletterModal">
#      <h2>
#       Discover more on our blog
#      </h2>
#      <p class="h4-small">
#       Our blog contains the latest news and updates from the Conservation Evidence team, the Conservation Evidence Journal, and our global partners in evidence-based conservation.
#      </p>
#      <hr/>
#      <a class="button button--green primary button--with-icon button--with-icon_right newsletter--btn w-100" href="https://about.conservationevidence.com/blog/" target="_blank">
#       Go to the Conservation Evidence blog
#      </a>
#     </div>
#    </div>
#   </div>
#  </section>
#  <!-- Newsletter section ends here -->
#  <!-- Newsletter/Twitter section ends here -->
#  <!-- "Meet the evidence champions" section - Starts -->
#  <div class="cms node-block">
#   <div class="node-content">
#    <div class="evidence-champions">
#     <div class="container">
#      <div class="evidence-champions__heading">
#       <h2>
#        Who uses Conservation Evidence?
#       </h2>
#       <h4>
#        Meet some of the evidence champions
#       </h4>
#      </div>
#      <div class="evidence-champions__body">
#       <div class="row">
#        <div class="col-12">
#         <figure>
#          <img alt="Endangered Landscape Programme" src="../../../../images/ELSP Portrait_RGB.jpg">
#           <img alt="Red List" src="../../../../images/red-list.png"/>
#           <img alt="Champion - Arc" src="../../../../images/ARC full (full colour))_2023.JPG"/>
#           <img alt="Kent Wildlife Trust" src="../../../../images/kent.png"/>
#           <img alt="The Rufford Foundation" src="../../../../images/Rufford.png"/>
#           <img alt="Save the Frogs - Ghana" src="../../../../images/ghana.png"/>
#           <img alt="Mauritian Wildlife" src="../../../../images/Mauritian Wildlife Logo Colour.jpg"/>
#           <img alt="Supporting Conservation Leaders" src="../../../../images/wfn.png"/>
#           <img alt="" src="../../../../images/bto.png"/>
#          </img>
#         </figure>
#         <figure>
#          <img alt="Sustainability Dashboard" src="../../../../images/nz.png"/>
#          <img alt="National Biodiversity Network" src="../../../../images/nbn.png"/>
#          <img alt="Frog Life" src="../../../../images/froglife.png"/>
#          <img alt="The international journey of Conservation - Oryx" src="../../../../images/oryx.png"/>
#          <img alt="Cool Farm Alliance" src="../../../../images/cfa.png"/>
#          <img alt="UNEP AWFA" src="../../../../images//aewa_logo_with_subline.jpg"/>
#          <img alt="Bat Conservation International" src="../../../../images/bci.jpg"/>
#          <img alt="People trust for endangered species" src="../../../../images/PTES-logo.png"/>
#          <img alt="Vincet Wildlife Trust" src="../../../../images/vwt.png"/>
#         </figure>
#        </div>
#       </div>
#      </div>
#      <div class="evidence-champions__footer mt-4">
#       <div class="row">
#        <div class="col-md-6 col-lg-4 mb-4 mb-md-0">
#         <h6>
#          For a full list of, and information about, our champions:
#         </h6>
#         <a class="button button--green button--with-icon button--with-icon_right" href="../../content/page/112">
#          All Evidence Champions
#         </a>
#        </div>
#        <div class="col-md-6 col-lg-4 pl-lg-4">
#         <h6>
#          About our champions, why and how to become one:
#         </h6>
#         <a class="button button--with-icon button--with-icon_right" href="../../content/page/118">
#          Become an Evidence Champion
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <!-- "Meet the evidence champions" section - Ends -->
#  <!-- footer starts here -->
#  <footer class="footer">
#   <div class="container">
#    <div class="row">
#     <div class="col-lg-3 footer__address notranslate">
#      <address>
#       <span>
#        Conservation Evidence
#       </span>
#       <span>
#        Department of Zoology
#       </span>
#       <span>
#        University of Cambridge
#       </span>
#       <span>
#        David Attenborough Building
#       </span>
#       <span>
#        Pembroke Street
#       </span>
#       <span>
#        Cambridge
#       </span>
#       <span>
#        CB2 3QZ
#       </span>
#      </address>
#      <p>
#       © 2024 ConservationEvidence.com
#      </p>
#     </div>
#     <div class="col-lg-3 footer__listing">
#      <ul>
#       <li>
#        <a href="/content/page/24">
#         About Conservation Evidence
#        </a>
#       </li>
#       <li>
#        <a href="/faq/index">
#         FAQs
#        </a>
#       </li>
#       <li>
#        <a href="/site/contact">
#         Contact us
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-lg-3 footer__maintainance">
#      <p>
#       Designed and maintained by:
#       <a href="http://thisismodular.co.uk/" target="_blank">
#        Modular Digital
#       </a>
#      </p>
#     </div>
#     <div class="col-lg-3 footer__social-block">
#      <ul>
#       <li>
#        <a href="https://www.facebook.com/conservationevidence" target="_blank">
#         <i class="fab fa-facebook-f">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a href="https://twitter.com/ConservEvidence" target="_blank">
#         <i class="fab fa-twitter">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.youtube.com/channel/UCWCc60LUK2SVXXxDBBo_44w?sub_confirmation=1" target="_blank">
#         <i class="fab fa-youtube">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.linkedin.com/company/conservation-evidence/" target="_blank">
#         <i class="fab fa-linkedin">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#  </footer>
#  <!-- footer ends here -->
#  <!-- Cookie bar starts here -->
#  <!-- Will not show if cookies accepted -->
#  <!-- Footer Cookie bar -->
#  <section class="cookie-banner">
#   <div class="container">
#    <div class="row">
#     <div class="col-12">
#      <h4>
#       This website uses Cookies
#      </h4>
#      <div class="cookie-banner__content">
#       <p>
#        We use limited Cookies to run the site and to analyse our traffic (none for site vendors). By using this site, you will be providing your consent to our use of Cookies.
#       </p>
#       <a class="button button--orange cookie-dismiss" href="javascript:void(0);">
#        Accept &amp; continue
#        <i class="fal fa-chevron-right">
#        </i>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </section>
#  <!-- Cookie bar ends here -->
#  <div class="modal hide fade" id="cat-modal">
#   <!-- BROWSE EVIDENCE 'WIDGET' -->
#   <section id="browse-evidence-container">
#    <div class="span12" id="browse-evidence">
#     <div class="pane active" id="select-category">
#      <h3>
#       <span>
#        1
#       </span>
#       Select a category
#      </h3>
#      <ul>
#       <li class="birds">
#        <a class="category-browser" data-id="6">
#         Birds
#        </a>
#       </li>
#       <li class="marshes-and-swamps">
#        <a class="category-browser" data-id="535">
#         Marshes and Swamps
#        </a>
#       </li>
#       <li class="reptiles">
#        <a class="category-browser" data-id="582">
#         Reptiles
#        </a>
#       </li>
#       <li class="terrestrial-mammals">
#        <a class="category-browser" data-id="444">
#         Terrestrial Mammals
#        </a>
#       </li>
#       <li class="subtidal-benthic-invertebrates">
#        <a class="category-browser" data-id="392">
#         Subtidal benthic invertebrates
#        </a>
#       </li>
#       <li class="bats">
#        <a class="category-browser" data-id="182">
#         Bats
#        </a>
#       </li>
#       <li class="marine-and-freshwater-mammals">
#        <a class="category-browser" data-id="491">
#         Marine and Freshwater Mammals
#        </a>
#       </li>
#       <li class="control-of-freshwater-invasive-species">
#        <a class="category-browser" data-id="216">
#         Control of Freshwater Invasive Species
#        </a>
#       </li>
#       <li class="primates">
#        <a class="category-browser" data-id="297">
#         Primates
#        </a>
#       </li>
#       <li class="amphibians">
#        <a class="category-browser" data-id="123">
#         Amphibians
#        </a>
#       </li>
#       <li class="peatlands">
#        <a class="category-browser" data-id="355">
#         Peatlands
#        </a>
#       </li>
#       <li class="butterflies-and-moths">
#        <a class="category-browser" data-id="643">
#         Butterflies and moths
#        </a>
#       </li>
#       <li class="forest">
#        <a class="category-browser" data-id="236">
#         Forest
#        </a>
#       </li>
#       <li class="farmland">
#        <a class="category-browser" data-id="16">
#         Farmland
#        </a>
#       </li>
#       <li class="shrublands-and-heathlands">
#        <a class="category-browser" data-id="330">
#         Shrublands and Heathlands
#        </a>
#       </li>
#       <li class="captive-animals">
#        <a class="category-browser" data-id="273">
#         Captive Animals
#        </a>
#       </li>
#       <li class="marine-fish">
#        <a class="category-browser" data-id="478">
#         Marine fish
#        </a>
#       </li>
#       <li class="mediterranean-farmland no-children">
#        <a class="category-browser" data-id="289">
#         Mediterranean Farmland
#        </a>
#       </li>
#       <li class="bees">
#        <a class="category-browser" data-id="5">
#         Bees
#        </a>
#       </li>
#       <li class="marine-artificial-structures">
#        <a class="category-browser" data-id="579">
#         Marine artificial structures
#        </a>
#       </li>
#       <li class="grassland">
#        <a class="category-browser" data-id="576">
#         Grassland
#        </a>
#       </li>
#       <li class="soils">
#        <a class="category-browser" data-id="2">
#         Soils
#        </a>
#       </li>
#       <li class="aquaculture">
#        <a class="category-browser" data-id="3">
#         Aquaculture
#        </a>
#       </li>
#       <li class="natural-pest-control">
#        <a class="category-browser" data-id="4">
#         Natural Pest Control
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="pane" id="refine-category">
#      <h3>
#       <span>
#        2
#       </span>
#       Refine category
#      </h3>
#      <div class="categories_container">
#      </div>
#     </div>
#     <div class="pane" id="refine-category-further">
#      <h3>
#       <span>
#        3
#       </span>
#       View actions
#      </h3>
#      <div class="categories_container">
#      </div>
#     </div>
#    </div>
#    <button id="browse-expand">
#    </button>
#   </section>
#  </div>
#  <!-- Google tag (gtag.js) -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-W381KRNN3T">
#  </script>
#  <script>
#   window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-W381KRNN3T');
#  </script>
#  <script src="/assets/2f77d0f8/listview/jquery.yiilistview.js" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   /*<![CDATA[*/
# var selectURL = "/data/select";
# var categoriesURL = "/category/fetch?";
# jQuery(function($) {
# jQuery('#yw0').yiiListView({'ajaxUpdate':[],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'list-view-loading','sorterClass':'sorter','enableHistory':false});
# });
# /*]]>*/
#  </script>
# </body>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())

# %%
studies = soup.find_all('td', attrs={'data-head': 'Studies'})

# %%
l = []

for study in tqdm(studies):
    l.append(int(study.find('a').get('href').removeprefix('/individual-study/')))
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
max(l)
# Out:
# 12579

# %%
l
# Out:
# [12579,
#  12578,
#  12577,
#  12576,
#  12574,
#  12575,
#  12573,
#  12572,
#  12571,
#  12569,
#  12570,
#  12567,
#  12568,
#  12566,
#  12564,
#  12565,
#  12563,
#  12562,
#  12561,
#  12560,
#  12559,
#  12558,
#  12556,
#  12557,
#  12555]

# %%
def get_latest_study_id():
    print('Retrieving the latest study ID...')
    print('Accessing Conservation Evidence website...')
    link = 'https://www.conservationevidence.com/data/studies?terms=&sort=created_at#searchcontainer'
    response = requests.get(link)
    print('Parsing the website to obtain the most recent studies...')

    soup = BeautifulSoup(response.text, 'html.parser')
    studies = soup.find_all('td', attrs={'data-head': 'Studies'})
    l = []
    for study in studies:
        l.append(int(study.find('a').get('href').removeprefix('/individual-study/')))

    print(f'Found latest study ID: {max(l)}. Preparing to scrape studies...')
    return max(l)

# %%
get_latest_study_id()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# 12579
